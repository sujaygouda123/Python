# %% [markdown]
# ## 1. Creating a List
#
# A list is an ordered, mutable collection created with square brackets `[]`. Items can be of any type and don't need to be unique.

# %% [markdown]
# # Python Lists — Practice Notebook
#
# A hands-on tour of core `list` operations in Python: creating lists, adding/removing items, ordering, searching, copying, and slicing — capped off with a mini **Student Management System** project that ties the methods together.

# %%
# Example 1
employees = ["John", "Alice", "Rahul", "Sujay"]

print(employees)

# %%
# Example 2
prices = [250, 899, 1200, 499]

print(prices)

# %%
# Example 3
marks = [78, 85, 92, 67, 54]

print(marks)

# %%
# Example 4
cities = ["Hubli", "Bangalore", "Mysore", "Belagavi"]

print(cities)

# %% [markdown]
# ## 1.2. `append()`
#
# Adds a single item to the **end** of the list, in place.

# %%
# Example 1
employees = ["John", "Alice"]
new_employee = input("Enter Employee Name: ")
new_employee =  new_employee.capitalize()
employees.append(new_employee)
print(employees)

# %%
# Example 2
products = ["Laptop", "Mouse"]
products.append("Keyboard")
print(products)

# %%
# Example 3
customers = []
customers.append("Ramesh")
customers.append("suresh")

customers = [name.capitalize() for name in customers]

print(customers)

# %%
# Example 4
sales = []
sales.append(12000)
sales.append(15000)
print(sales)

# %% [markdown]
# ## 1.3. `insert()`
#
# Inserts an item at a specific **index**, shifting later items to the right.

# %%
# Example 1
tasks = ["Testing", "deployment"]
tasks.insert(0, "Bug Fix")
print(tasks)

# %%
# Example 2
customers = ["Rahul", "Amit"]
customers.insert(0, "VIP Customer")
print(customers)

# %%
# Example 3
subjects = ["Math","Science"]
subjects.insert(1,"Sst")
print(subjects)

# %%
# Example 4
employees= ["John","David"]
employees.insert(1, "Alice")
print(employees)

# %% [markdown]
# ## 1.4. `extend()`
#
# Appends **all items** from another iterable onto the end of the list (unlike `append()`, which would add the whole iterable as one item).

# %%
# Example 1
team_1 = ["John","Alice"]
team_2 = ["David","Rahul"]
team_1.extend(team_2)
print(team_1)

# %%
# Example 2
electronics =["Laptop","TV"]
accessories = ["Mouse","Keyboard"]
electronics.extend(accessories)
print(electronics)

# %%
# Example 3
classA = ["Ram", "Sam"]
classB = ["Tom", "Jerry"]

classA.extend(classB)

print(classA)

# %%
# Example 4
hubli = ["Store1", "Store2"]
bangalore = ["Store3"]

hubli.extend(bangalore)

print(hubli)

# %% [markdown]
# ## 1.5. `remove()`
#
# Removes the **first matching value** from the list. Raises `ValueError` if the value isn't found.

# %%
# Example 1
employees = ["John", "Alice", "Rahul"]

employees.remove("Alice")

print(employees)

# %%
# Example 2
products = ["Laptop", "Mouse", "Keyboard"]

products.remove("Mouse")

print(products)

# %%
# Example 3
orders = ["Order1", "Order2", "Order3"]

orders.remove("Order2")

print(orders)

# %%
# Example 4
students = ["Ram","Sam","Tom"]
students.remove("Sam")
print(students)

# %% [markdown]
# ## 1.6. `pop()`
#
# Removes and **returns** the last item (or the item at a given index) — the only removal method that gives the value back.

# %%
# Example 1
queue = ["A","B","C"]
served = queue.pop()
print(served)
print(queue)

# %%
# Example 2
products = ["Laptop","TV","Mouse"]
products.pop()
print(products)

# %%
# Example 3
tasks = ["Login", "Upload", "Logout"]

tasks.pop()

print(tasks)

# %%
# Example 4
attendance = ["John", "Alice", "Rahul"]

attendance.pop()

print(attendance)

# %% [markdown]
# ## 1.7. `clear()`
#
# Removes **all** items, leaving an empty list in place.

# %%
# Example 1
cart = ["Laptop","Mouse","Keyboard"]
cart.clear()
print(cart)

# %%
# Example 2
attendance = ["present","absent"]
attendance.clear()
print(attendance)

# %%
# Example 3
notifications = ["Email", "SMS"]

notifications.clear()

print(notifications)

# %%
# Example 4
queue = ["A", "B", "C"]

queue.clear()

print(queue)

# %% [markdown]
# ## 1.8. `sort()`
#
# Sorts the list **in place**, ascending by default. Use `sort(reverse=True)` for descending order.

# %%
# Example 1
employees = ["Rahul", "Alice", "John"]

employees.sort()

print(employees)

# %%
# Example 2
prices = [250, 1000, 150, 600]

prices.sort()

print(prices)

# %%
# Example 3
marks = [78, 45, 91, 66]

marks.sort()

print(marks)

# %%
# Example 4
cities = ["Hubli", "Delhi", "Bangalore"]

cities.sort()

print(cities)

# %% [markdown]
# ## 1.9. `reverse()`
#
# Reverses the order of items **in place** (not a sort — just flips the current order).

# %%
# Example 1
orders = ["Order1", "Order2", "Order3"]

orders.reverse()

print(orders)

# %%
# Example 2
employees = ["John", "Alice", "David"]

employees.reverse()

print(employees)

# %%
# Example 3
numbers = [10, 20, 30, 40]

numbers.reverse()

print(numbers)

# %%
# Example 4
cities = ["Hubli", "Delhi", "Mumbai"]

cities.reverse()

print(cities)

# %% [markdown]
# ## 1.10. `count()`
#
# Returns how many times a value appears in the list.

# %%
# Example 1
attendance = ["Present", "Absent", "Present", "Present"]

print(attendance.count("Present"))

# %%
# Example 2
products =['mouse','keyboard','mouse','laptop']
print(products.count('mouse'))

# %%
# Example 3
votes = ['a','a','b','a','c','c','a']
print(votes.count('a'))

# %% [markdown]
# ## 1.11. `index()`
#
# Returns the position of the **first match** of a value. Raises `ValueError` if not found.

# %%
# Example 1
employees =['john','alice','rahul']
print(employees.index("alice"))

# %%
# Example 2
products = ['laptop','tv','mouse']
print(products.index('tv'))

# %%
# Example 3
students =['ram','sam','tom']
print(students.index('tom'))

# %%
# Example 4
departments = ['hr','it','finance']
print(departments.index('it'))

# %% [markdown]
# ## 1.12. `copy()`
#
# Returns a **shallow copy** of the list. Without it, `backup = original` just points both names at the same list — mutating one mutates the other, as the last example below shows.

# %%
# Example 1
employees = ["John", "Alice"]

backup = employees.copy()

print(backup)

# %%
# Example 2
cart = ["Laptop", "Mouse"]

cart_backup = cart.copy()

print(cart_backup)

# %%
# Example 3
attendance = ["Present", "Absent"]

attendance_backup = attendance.copy()

print(attendance_backup)

# %%
# Example 4
products = ['tv','laptop']
#backup = products.copy()
backup = products
print(backup)

# %% [markdown]
# ## 1.13. List Slicing
#
# Extracts a sub-list using `list[start:stop]`. Negative indices count from the end, so `list[-2:]` grabs the last two items.

# %%
# Example 1
employees = ["John", "Alice", "Rahul", "David", "Rohan"]

print(employees[:3])

# %%
# Example 2
products = ["TV", "Laptop", "Mouse", "Keyboard"]

print(products[-2:])

# %%
# Example 3
marks = [91, 88, 85, 80, 78, 75]

print(marks[:5])

# %%
# Example 4
orders = ["O1", "O2", "O3", "O4", "O5"]

print(orders[-3:])

# %% [markdown]
# ## 2. Mini Project — Student Management System
#
# A menu-driven CLI that combines `append`, `index`, `remove`, and `len` to add, view, search, update, remove, and count students.

# %%
students = []

while True:
    print("\n===== Student Management System =====")
    print("1. Add Student")
    print("2. View Students")
    print("3. Search Student")
    print("4. Update Student")
    print("5. Remove Student")
    print("6. Count Students")
    print("7. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        name = input("Enter Student Name: ").title()

        if name not in students:
            students.append(name)
            print(name, "added successfully.")
        else:
            print("Student already exists.")

    elif choice == "2":
        if students:
            print("\nStudent List")
            for i, student in enumerate(students, start=1):
                print(i, student)
        else:
            print("No students available.")

    elif choice == "3":
        name = input("Enter Student Name to Search: ").title()

        if name in students:
            position = students.index(name) + 1
            print(name, "found at position", position)
        else:
            print("Student not found.")

    elif choice == "4":
        old_name = input("Enter Student Name to Update: ").title()

        if old_name in students:
            new_name = input("Enter New Student Name: ").title()
            index = students.index(old_name)
            students[index] = new_name
            print("Student details updated.")
        else:
            print("Student not found.")

    elif choice == "5":
        name = input("Enter Student Name to Remove: ").title()

        if name in students:
            students.remove(name)
            print(name, "removed successfully.")
        else:
            print("Student not found.")

    elif choice == "6":
        print("Total Students:", len(students))

    elif choice == "7":
        print("Thank you for using Student Management System.")
        break

    else:
        print("Invalid Choice.")
# Out:
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Remove Student
# 6. Count Students
# 7. Exit
# Enter your choice:  1
# Enter Student Name:  sujay
# Sujay added successfully.
#
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Remove Student
# 6. Count Students
# 7. Exit
# Enter your choice:  2
# Student List
# 1 Sujay
#
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Remove Student
# 6. Count Students
# 7. Exit
# Enter your choice:  5
# Enter Student Name to Remove:  ram
# Student not found.
#
# ===== Student Management System =====
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Student
# 5. Remove Student
# 6. Count Students
# 7. Exit
# Enter your choice:  7
# Thank you for using Student Management System.
